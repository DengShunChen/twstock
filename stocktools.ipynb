# %%
from stocktools import StockTools

# %%
st = StockTools('2018-06-01','2018-08-31')

# %%
#st.plot('1101','20180801')

# %%
st.fetch_all()

# %%
st.strdate = '2018-07-01'
st.enddate = None

# %%
st.plot('2345')
